# %%
# import the libraries
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential


import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
!7z x /content/drive/MyDrive/Classes.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 190278912 bytes (182 MiB)
#
# Extracting archive: /content/drive/MyDrive/Classes.zip
# --
# Path = /content/drive/MyDrive/Classes.zip
# Type = zip
# Physical Size = 190278912
#
# Everything is Ok
#
# Folders: 5
# Files: 10306
# Size:       190557255
# Compressed: 190278912

# %%
import pathlib
data_dir = '/content/Classes'
data_dir = pathlib.Path(data_dir)

# %%
from pathlib import Path
import imghdr

# %%
image_count = len(list(data_dir.glob('*/*.jpeg')))
print(image_count)
# Out:
# 10304

# %%
batch_size = 32
img_height = 256
img_width = 256

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    shuffle = True, #to select random image
    image_size = (img_height, img_width),
    batch_size = batch_size)
# Out:
# Found 10304 files belonging to 2 classes.

# %%
class_names = dataset.class_names
print(class_names)
# Out:
# [' No_DR', 'DR']

# %%
#training images
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10304 files belonging to 2 classes.
# Using 7213 files for training.

# %%
#testing images
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10304 files belonging to 2 classes.
# Using 3091 files for validation.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical", input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.5, seed=None),
    layers.RandomCrop(150, 150, seed=None)
  ]
)

# %%
number_classes = len(class_names)

from keras.layers import  Dropout, BatchNormalization
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

model = models.Sequential([
        layers.Conv2D(32, (3,3), input_shape=(256,256,3), strides=(1, 1), activation='relu',padding='same'),
        layers.MaxPool2D(pool_size=(2, 2), padding='same'),
        layers.BatchNormalization(),
        layers.Dropout(0.25),

        layers.Conv2D(64, (5, 5), activation='relu', strides=(1, 1), padding='valid'),
        layers.MaxPool2D(pool_size=(4, 4), padding='valid'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(32, activation='relu'),
        layers.Dense(number_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 124, 124, 64)      51264
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 31, 31, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 31, 31, 64)        0
#
#  flatten (Flatten)           (None, 61504)             0
#
#  dense (Dense)               (None, 512)               31490560
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 31,717,730
# Trainable params: 31,717,538
# Non-trainable params: 192
# _________________________________________________________________

# %%
import time
start_cnn = time.time()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

path = 'best_model_den.hdf5'
checkpoint = ModelCheckpoint(path, monitor='val_accuracy', verbose = 1, save_best_only = True, mode='max')
es = EarlyStopping(monitor='val_accuracy', patience=10)

callback_list = [checkpoint,es]

# %%
#model compilation
model.compile(optimizer= 'Adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=callback_list
)
# Out:
# Epoch 1/100
# 226/226 [==============================] - ETA: 0s - loss: 1.3699 - accuracy: 0.5028
# Epoch 1: val_accuracy improved from -inf to 0.50696, saving model to best_model_den.hdf5
# 226/226 [==============================] - 36s 115ms/step - loss: 1.3699 - accuracy: 0.5028 - val_loss: 0.6950 - val_accuracy: 0.5070
# Epoch 2/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5089
# Epoch 2: val_accuracy did not improve from 0.50696
# 226/226 [==============================] - 23s 102ms/step - loss: 0.7276 - accuracy: 0.5088 - val_loss: 0.6952 - val_accuracy: 0.5018
# Epoch 3/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.7188 - accuracy: 0.5004
# Epoch 3: val_accuracy did not improve from 0.50696
# 226/226 [==============================] - 24s 106ms/step - loss: 0.7188 - accuracy: 0.5001 - val_loss: 0.6938 - val_accuracy: 0.5024
# Epoch 4/100
# 226/226 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.5145
# Epoch 4: val_accuracy did not improve from 0.50696
# 226/226 [==============================] - 29s 126ms/step - loss: 0.7032 - accuracy: 0.5145 - val_loss: 0.6970 - val_accuracy: 0.4950
# Epoch 5/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.7015 - accuracy: 0.5051
# Epoch 5: val_accuracy did not improve from 0.50696
# 226/226 [==============================] - 23s 100ms/step - loss: 0.7015 - accuracy: 0.5049 - val_loss: 0.6944 - val_accuracy: 0.4992
# Epoch 6/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6973 - accuracy: 0.5149
# Epoch 6: val_accuracy did not improve from 0.50696
# 226/226 [==============================] - 25s 108ms/step - loss: 0.6973 - accuracy: 0.5150 - val_loss: 0.6952 - val_accuracy: 0.5005
# Epoch 7/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.7015 - accuracy: 0.5125
# Epoch 7: val_accuracy improved from 0.50696 to 0.51666, saving model to best_model_den.hdf5
# 226/226 [==============================] - 24s 105ms/step - loss: 0.7015 - accuracy: 0.5123 - val_loss: 0.6916 - val_accuracy: 0.5167
# Epoch 8/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6946 - accuracy: 0.5258
# Epoch 8: val_accuracy did not improve from 0.51666
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6946 - accuracy: 0.5260 - val_loss: 0.6937 - val_accuracy: 0.4998
# Epoch 9/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6941 - accuracy: 0.5089
# Epoch 9: val_accuracy did not improve from 0.51666
# 226/226 [==============================] - 24s 104ms/step - loss: 0.6941 - accuracy: 0.5088 - val_loss: 0.6923 - val_accuracy: 0.5099
# Epoch 10/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6921 - accuracy: 0.5242
# Epoch 10: val_accuracy improved from 0.51666 to 0.52960, saving model to best_model_den.hdf5
# 226/226 [==============================] - 25s 112ms/step - loss: 0.6921 - accuracy: 0.5242 - val_loss: 0.6909 - val_accuracy: 0.5296
# Epoch 11/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6896 - accuracy: 0.5424
# Epoch 11: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6895 - accuracy: 0.5428 - val_loss: 0.6945 - val_accuracy: 0.5018
# Epoch 12/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6842 - accuracy: 0.5622
# Epoch 12: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 103ms/step - loss: 0.6842 - accuracy: 0.5625 - val_loss: 0.6968 - val_accuracy: 0.4963
# Epoch 13/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6867 - accuracy: 0.5521
# Epoch 13: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 103ms/step - loss: 0.6866 - accuracy: 0.5522 - val_loss: 0.6912 - val_accuracy: 0.5086
# Epoch 14/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6901 - accuracy: 0.5456
# Epoch 14: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6902 - accuracy: 0.5457 - val_loss: 0.6957 - val_accuracy: 0.4960
# Epoch 15/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6873 - accuracy: 0.5519
# Epoch 15: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 103ms/step - loss: 0.6872 - accuracy: 0.5521 - val_loss: 0.6941 - val_accuracy: 0.5011
# Epoch 16/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6852 - accuracy: 0.5583
# Epoch 16: val_accuracy did not improve from 0.52960
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6851 - accuracy: 0.5587 - val_loss: 0.6948 - val_accuracy: 0.4963
# Epoch 17/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6885 - accuracy: 0.5494
# Epoch 17: val_accuracy improved from 0.52960 to 0.53090, saving model to best_model_den.hdf5
# 226/226 [==============================] - 25s 108ms/step - loss: 0.6886 - accuracy: 0.5494 - val_loss: 0.6892 - val_accuracy: 0.5309
# Epoch 18/100
# 226/226 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.5532
# Epoch 18: val_accuracy did not improve from 0.53090
# 226/226 [==============================] - 25s 110ms/step - loss: 0.6862 - accuracy: 0.5532 - val_loss: 0.6911 - val_accuracy: 0.5176
# Epoch 19/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6911 - accuracy: 0.5506
# Epoch 19: val_accuracy did not improve from 0.53090
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6912 - accuracy: 0.5505 - val_loss: 0.6942 - val_accuracy: 0.5063
# Epoch 20/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6881 - accuracy: 0.5486
# Epoch 20: val_accuracy improved from 0.53090 to 0.54934, saving model to best_model_den.hdf5
# 226/226 [==============================] - 25s 108ms/step - loss: 0.6880 - accuracy: 0.5491 - val_loss: 0.6861 - val_accuracy: 0.5493
# Epoch 21/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6842 - accuracy: 0.5576
# Epoch 21: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6842 - accuracy: 0.5579 - val_loss: 0.6922 - val_accuracy: 0.5082
# Epoch 22/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.5631
# Epoch 22: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 24s 104ms/step - loss: 0.6832 - accuracy: 0.5629 - val_loss: 0.6940 - val_accuracy: 0.5082
# Epoch 23/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6815 - accuracy: 0.5689
# Epoch 23: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6815 - accuracy: 0.5688 - val_loss: 0.6899 - val_accuracy: 0.5222
# Epoch 24/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6829 - accuracy: 0.5617
# Epoch 24: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 100ms/step - loss: 0.6829 - accuracy: 0.5615 - val_loss: 0.6920 - val_accuracy: 0.5150
# Epoch 25/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6787 - accuracy: 0.5735
# Epoch 25: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 102ms/step - loss: 0.6787 - accuracy: 0.5735 - val_loss: 0.6982 - val_accuracy: 0.5053
# Epoch 26/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6747 - accuracy: 0.5785
# Epoch 26: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 24s 104ms/step - loss: 0.6746 - accuracy: 0.5783 - val_loss: 0.6900 - val_accuracy: 0.5338
# Epoch 27/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6731 - accuracy: 0.5872
# Epoch 27: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6732 - accuracy: 0.5870 - val_loss: 0.6897 - val_accuracy: 0.5277
# Epoch 28/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.5792
# Epoch 28: val_accuracy did not improve from 0.54934
# 226/226 [==============================] - 23s 100ms/step - loss: 0.6734 - accuracy: 0.5795 - val_loss: 0.6860 - val_accuracy: 0.5493
# Epoch 29/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6790 - accuracy: 0.5856
# Epoch 29: val_accuracy improved from 0.54934 to 0.55128, saving model to best_model_den.hdf5
# 226/226 [==============================] - 24s 107ms/step - loss: 0.6789 - accuracy: 0.5855 - val_loss: 0.6840 - val_accuracy: 0.5513
# Epoch 30/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6732 - accuracy: 0.5860
# Epoch 30: val_accuracy did not improve from 0.55128
# 226/226 [==============================] - 24s 105ms/step - loss: 0.6732 - accuracy: 0.5862 - val_loss: 0.6969 - val_accuracy: 0.5015
# Epoch 31/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.5832
# Epoch 31: val_accuracy did not improve from 0.55128
# 226/226 [==============================] - 23s 102ms/step - loss: 0.6724 - accuracy: 0.5833 - val_loss: 0.6875 - val_accuracy: 0.5244
# Epoch 32/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5922
# Epoch 32: val_accuracy did not improve from 0.55128
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6713 - accuracy: 0.5924 - val_loss: 0.6887 - val_accuracy: 0.5357
# Epoch 33/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6665 - accuracy: 0.5986
# Epoch 33: val_accuracy did not improve from 0.55128
# 226/226 [==============================] - 24s 106ms/step - loss: 0.6667 - accuracy: 0.5984 - val_loss: 0.6926 - val_accuracy: 0.5218
# Epoch 34/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6586 - accuracy: 0.6160
# Epoch 34: val_accuracy did not improve from 0.55128
# 226/226 [==============================] - 24s 106ms/step - loss: 0.6587 - accuracy: 0.6157 - val_loss: 0.6856 - val_accuracy: 0.5490
# Epoch 35/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6625 - accuracy: 0.6015
# Epoch 35: val_accuracy improved from 0.55128 to 0.59010, saving model to best_model_den.hdf5
# 226/226 [==============================] - 24s 106ms/step - loss: 0.6625 - accuracy: 0.6014 - val_loss: 0.6759 - val_accuracy: 0.5901
# Epoch 36/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6553 - accuracy: 0.6137
# Epoch 36: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 103ms/step - loss: 0.6555 - accuracy: 0.6139 - val_loss: 0.6973 - val_accuracy: 0.5167
# Epoch 37/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6502 - accuracy: 0.6290
# Epoch 37: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 102ms/step - loss: 0.6501 - accuracy: 0.6291 - val_loss: 0.6805 - val_accuracy: 0.5662
# Epoch 38/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6449 - accuracy: 0.6281
# Epoch 38: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6448 - accuracy: 0.6283 - val_loss: 0.6976 - val_accuracy: 0.5306
# Epoch 39/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6341 - accuracy: 0.6422
# Epoch 39: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 24s 105ms/step - loss: 0.6342 - accuracy: 0.6419 - val_loss: 0.7009 - val_accuracy: 0.5432
# Epoch 40/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6244 - accuracy: 0.6538
# Epoch 40: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 103ms/step - loss: 0.6244 - accuracy: 0.6538 - val_loss: 0.6988 - val_accuracy: 0.5490
# Epoch 41/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.6162 - accuracy: 0.6669
# Epoch 41: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 101ms/step - loss: 0.6161 - accuracy: 0.6670 - val_loss: 0.6832 - val_accuracy: 0.5804
# Epoch 42/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.5926 - accuracy: 0.6831
# Epoch 42: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 24s 106ms/step - loss: 0.5923 - accuracy: 0.6833 - val_loss: 0.7080 - val_accuracy: 0.5581
# Epoch 43/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.5820 - accuracy: 0.6918
# Epoch 43: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 101ms/step - loss: 0.5824 - accuracy: 0.6917 - val_loss: 0.7312 - val_accuracy: 0.5296
# Epoch 44/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.5631 - accuracy: 0.7051
# Epoch 44: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 100ms/step - loss: 0.5632 - accuracy: 0.7050 - val_loss: 0.7133 - val_accuracy: 0.5620
# Epoch 45/100
# 225/226 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7294
# Epoch 45: val_accuracy did not improve from 0.59010
# 226/226 [==============================] - 23s 101ms/step - loss: 0.5394 - accuracy: 0.7295 - val_loss: 0.7234 - val_accuracy: 0.5697

# %%
scores = model.evaluate(train_ds)
# Out:
# 226/226 [==============================] - 9s 38ms/step - loss: 0.4884 - accuracy: 0.7947

# %%
scores = model.evaluate(val_ds)
# Out:
# 97/97 [==============================] - 4s 38ms/step - loss: 0.7234 - accuracy: 0.5697

# %%
plt.style.use('fivethirtyeight')

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.style.use('fivethirtyeight')

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
X = []
y = []
for image,labels in val_ds.take(96):
    for i in image:
        img = i.numpy()
        X.append(img)
    lbl_list = labels.numpy()    
    y.extend(lbl_list)

# %%
x = np.array(X)

# %%
y = np.array(y)

# %%
x.shape
# Out:
# (3072, 256, 256, 3)

# %%
y.shape
# Out:
# (3072,)

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred = model.predict(x[:3072])
y_pred_classes = [np.argmax(element) for element in y_pred]
 
print("Classification Report: \n", classification_report(y[:3072], y_pred_classes))
# Out:
# 96/96 [==============================] - 2s 23ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.45      0.51      1559
#            1       0.55      0.70      0.61      1513
#
#     accuracy                           0.57      3072
#    macro avg       0.58      0.57      0.56      3072
# weighted avg       0.58      0.57      0.56      3072

# %%
plt.style.use('fivethirtyeight')

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.style.use('fivethirtyeight')

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
